# %% [markdown]
# # BTDet-Multimodal — Full Training Notebook
#
# **Run this notebook in Google Colab for best results (T4 GPU)**
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/YOUR_USERNAME/BTDet-Multimodal/blob/main/notebooks/BTDet_Multimodal_Full.ipynb)
#
# ## Stages
# - Stage 1: Data Pipeline
# - Stage 2: Baseline YOLOv8-N
# - Stage 3: 4-Channel Fusion (Novelty 1)
# - Stage 4: FiLM Clinical Injection (Novelty 2)
# - Stage 5: Multi-Task Survival Head (Novelty 3)
# - Stage 6: Grad-CAM Visualizations
